# %% [markdown]
# <a href="https://colab.research.google.com/github/LINC42/api-youtube-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import requests
import pandas as pd
import time

# %%
#key
API_KEY = "XXXXXXXXX"
CHANNEL_ID = "UCW8Ews7tdKKkBT6GdtQaXvQ"

# %%
#make API call
pageToken = ""
url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000"+pageToken

response = requests.get(url).json()

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'z2qQcXuGrk-XTj4B3wSjAYmnYe8',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'US',
#  'pageInfo': {'totalResults': 118, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'VRgkNB5nGBbVi5q8IUFsjl9vySk',
#    'id': {'kind': 'youtube#video', 'videoId': 'RmMuS5iiviI'},
#    'snippet': {'publishedAt': '2022-11-03T15:30:05Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Python Pandas Techniques In A Meta Data Science Interview',
#     'description': "In this video, we'll walk you through a difficult data science interview question from Meta and then provide a Python solution.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RmMuS5iiviI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RmMuS5iiviI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...
