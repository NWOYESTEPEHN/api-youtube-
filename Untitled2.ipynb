# %% [markdown]
# <a href="https://colab.research.google.com/github/NWOYESTEPEHN/api-youtube-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import requests
import pandas as pd
import time

# %%
#key
API_KEY = "AIzaSyADCb97PoGuk3sewvvmeb_COGisPRI_UyU"
CHANNEL_ID = "UCW8Ews7tdKKkBT6GdtQaXvQ"

# %%
#make API call
pageToken = ""
url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000"+pageToken

response = requests.get(url).json()

# %%
response['items'][1]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'VtKLUuDytFoYeE1x3KHE76cb7a8',
#  'id': {'kind': 'youtube#video', 'videoId': 'bppeYE-VUSQ'},
#  'snippet': {'publishedAt': '2022-10-31T02:00:07Z',
#   'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#   'title': 'Data Science Interview Simple Tips: How to Answer the Additional Question',
#   'description': "In this video, we're going to discuss a few tips that will help you answer the additional question during the coding interview.",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/bppeYE-VUSQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/bppeYE-VUSQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/bppeYE-VUSQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'StrataScratch',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2022-10-31T02:00:07Z'}}

# %%
#build our dataframe
df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count","comment_count"])

# %%
df
# Out:
# Empty DataFrame
# Columns: [video_id, video_title, upload_date, view_count, like_count, comment_count]
# Index: []

# %%
for video in response['items']:
      if video['id']['kind'] == "youtube#video":
          video_id = video['id']['videoId']
          video_title = video['snippet']['title']
          video_title = str(video_title).replace("&amp;","")
          upload_date = response['items'][0]['snippet']['publishedAt']
          upload_date = str(upload_date).split('T')[0]
          
          #collecting view
          url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
          response_video_stats = requests.get(url_video_stats).json()
          
          view_count = response_video_stats['items'][0]['statistics']['viewCount']
          like_count = response_video_stats['items'][0]['statistics']['likeCount']
          comment_count = response_video_stats['items'][0]['statistics']['commentCount']

          #save data in pandas df
          df = df.append({'video_id':video_id,'video_title':video_title,
                          "upload_date":upload_date,"view_count":view_count,
                          "like_count":like_count,
                          "comment_count":comment_count},ignore_index=True)

# %%
df
# Out:
#        video_id                                        video_title  \
# 0   RmMuS5iiviI  Python Pandas Techniques In A Meta Data Scienc...
# 1   bppeYE-VUSQ  Data Science Interview Simple Tips: How to Ans...
# 2   0EKPN19Y9MA  How many Twitch viewers became streamers? A SQ...
# 3   vQmk0bH25d0  [Part 2] EDGE Cases in Data Analysis: How to R...
# 4   M-dT_0m4qhI  SQL interview: How many Twitch viewers became ...
# 5   rEaSskQhId4  [Part 1] How to Solve an Amazon Python Intervi...
# 6   8IIryKHheYw  (Part 3) How to Formulate the Approach for Sol...
# 7   yQSZT65WET4     A Python Coding Interview Question From Amazon
# 8   OMHbYrL09io  A/B Testing (A) Interview Questions or (B) for...
# 9   SGDchcWjaTA  (Part 2) Deepen Your Understanding of Data wit...
# 10  9av7jQ9MA44      A/B Testing Concepts To Know For Data Science
# 11  nh2nLDpxDFI  (Part 1) Meta SQL Interview Question: Identify...
# 12  Q-3wvYInCeI  Meta SQL Interview Question - A Step-By-Step S...
# ...
