# %% [markdown]
# <a href="https://colab.research.google.com/github/NWOYESTEPEHN/api-youtube-/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import requests
import pandas as pd
import time

# %%
#keyaqR5g
API_KEY = "xxxxxxxxxxxx"
CHANNEL_ID = "MrBeast6000"

# %%
#make API call
pageToken =""
url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelid="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=1000000"+pageToken

response = requests.get(url).json()

# %%
response["items"][1]

# %%
#build our dataframe
df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count","comment_count"])

# %%
df

# %%
for video in response['items']:
    if video['id']['kind'] == "youtube#video":
      video_id = video['id']['videoId']
      video_title = video['snippet']['title']
      video_title = str(video_title).replace("&","")
      upload_date = response['items'][0]['snippet']['publishedAt']
      upload_date = str(upload_date).split('T')[0]

      #collecting view
      url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
      response_video_stats = requests.get(url_video_stats).json()

      view_count = response_video_stats['items'][0]['statistics']['commentCount']
      comment_count = response_video_stats['items'][0]['statistics']['commentCount']

      #save data in pandas df
      df = df.append({'video_id':video_id,'video_title':video_title,
                      "upload_date":upload_date,
                      "like_count":like_count,
                      "comment_count":comment_count}, ignore_index=True)

# %%
df
# Out:
#         video_id                                        video_title  \
# 0    9_0ZUUOF72U     ONE PIECE ODYSSEY | Water Seven Reveal Trailer
# 1    juJP_wbXyKo                          หนังตะลุงไข่แตก | Rivalry
# 2    t4W9954RVpg     Bom dia 247: Lula escala sua seleção (7.11.22)
# 3    bBxHZsBrn_Y                           #Live NewsHour  07-11-65
# 4    r-O8qEh-YE4  Apex Legends New Season 15 Collection Event am...
# ..           ...                                                ...
# 198  FdbvQoJ5R_o  【張若妤報新聞】爆陳時中摟人妻quot;遭綠委圍剿quot;徐巧芯回嗆quot;有影片還沒公...
# 199  epodcOXtj00  Kayal - Ep 331 | 05 November 2022 | Tamil Seri...
# 200  hOO9SnMhT1s  Soccor King | World Cup 2022 | Brand Oddbods N...
# 201  SCZFCESxnDk  SPINNING KICK KNOCKOUT 🤯🤯🤯 Kevin Belingon vs. ...
# 202  r__STRsad3k                  ハラハラドキドキ！　ラーマンさんは走れるのか！？　世界のマスー優勝
#
#     upload_date view_count like_count comment_count
# 0    2022-11-07        NaN        317            37
# ...
